# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# Import libraries

# %%
import pandas
import numpy
import matplotlib
import seaborn
import sqlalchemy

# %% [markdown]
# Initial empty dataframe

# %%
columns = ['Month', 'Category', 'Expense']
budget_data = pd.DataFrame(columns = columns)

# %% [markdown]
# Define Months, Category

# %%
Months = [
    "January", "Februrary", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"
]

Category = [
    "Income", "Expense", "School", "Retirement", "Utilities", "Entertainement", "Phone payment", "Groceries", "Eating Out", "Gas","Mortgage", "Misc"
]

# %% [markdown]
# Function asking for confirmation

# %%
def confirmation_all():
    while True:
        #Asks for confirmation. Will only take the first letter and puts it in lowercase
        confirmation = input("\nIs that correct?(Y/N): ").strip().lower()[0]

        if confirmation == "y":
            return True
        elif confirmation == "n":
            return False
        else:
            print("Invalid response. Please enter Y or N")

# %% [markdown]
# Code to ask which month to add new transaction to

# %%
def choose_month():
    while True:     
        try:
            #Ask for month input
            month_index = int(input("Choose a month by number (e.g. 1 for January): "))
            if 1 <= month_index <= 12:
                #Need to subtract 1 for array
                month = Months[month_index-1]
                print("You chose the month of: \n", month)
                if confirmation_all():
                    return month
                    break
                else:
                    continue
            #If number not within normal, then will ask again
            else:
                print("Invalid number. Please try again.")
        #If not a valid input, will ask again
        except ValueError:
            print("Invalid number. Please try again.")

# %% [markdown]
# Code to list and ask what category to add

# %%
def category_type():
    print("\nCategories:")
    for i, categories in enumerate(Category, start = 1):
        print(f"{i}. {categories}")
    while True:
        try:
            category_index = int(input("Choose a category to add to: "))
            if 1 <= category_index <= 12:
                #Need to subtract 1 for array
                category = Category[category_index - 1]
                print("You have chosen: ", category)
                if confirmation_all():
                    return category
                    break
                else:
                    continue                
            else:
                print("Invalid number. Please try again.")
        except ValueError:
            print("Invalid number. Please try again.")

# %% [markdown]
# Asking how much to add to the category and then repeating until finished.

# %%
def expense_amount(category):
    try:
        expense = float(input("How much was the expense?: "))

        expense = abs(expense)
        if category != 'Income':
            expense = -(expense)
        return expense
    except ValueError:
        print("Please enter a valid value.")

# %% [markdown]
# Append the transaction

# %%
def add_transaction(df):
    month = choose_month()
    category = category_type()
    expense = expense_amount(category)
    new_entry = {'Month': month, 'Category' : category, 'Expense' : expense}
    df = pd.concat([df, pd.DataFrame([new_entry])], ignore_index = True)
    print(f"Transaction added: {new_entry}")
    return df

# %% [markdown]
# Main Code

# %%
def main():
    global budget_data
    print("Budget Program")

    while True:
        print("\nOptions: 1. Add Transaction 2. View Data 3. Exit 4. Clear Data")
        choice = input("Please choose an option: ")

        if choice == '1':
            budget_data = add_transaction(budget_data)
        elif choice == '2':
            print("\nCurrent Budget Data")
            print(budget_data if not budget_data.empty else "No data available.")
        elif choice == '3':
            break
        elif choice == '4':
            budget_data.drop(budget_data.index, inplace = True)
        else:
            print("Invalid option. Please try again.")

if __name__ == "__main__":
    main()
# Out:
# Budget Program
#
# Options: 1. Add Transaction 2. View Data 3. Exit 4. Clear Data
# Please choose an option:  4
# Options: 1. Add Transaction 2. View Data 3. Exit 4. Clear Data
# Please choose an option:  1
# Choose a month by number (e.g. 1 for January):  1
# You chose the month of:
#  January
# Is that correct?(Y/N):  y
# Categories:
# 1. Income
# 2. Expense
# 3. School
# 4. Retirement
# 5. Utilities
# 6. Entertainement
# 7. Phone payment
# 8. Groceries
# 9. Eating Out
# 10. Gas
# 11. Mortgage
# 12. Misc
# Choose a category to add to:  1
# You have chosen:  Income
# Is that correct?(Y/N):  y
# How much was the expense?:  1000
# Transaction added: {'Month': 'January', 'Category': 'Income', 'Expense': 1000.0}
#
# Options: 1. Add Transaction 2. View Data 3. Exit 4. Clear Data
# Please choose an option:  2
# Current Budget Data
#      Month Category  Expense
# 0  January   Income   1000.0
#
# Options: 1. Add Transaction 2. View Data 3. Exit 4. Clear Data
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[67], line 22
#      19             print("Invalid option. Please try again.")
#      21 if __name__ == "__main__":
# ---> 22     main()
#
# Cell In[67], line 7, in main()
#       5 while True:
#       6     print("\nOptions: 1. Add Transaction 2. View Data 3. Exit 4. Clear Data")
# ----> 7     choice = input("Please choose an option: ")
#       9     if choice == '1':
#      10         budget_data = add_transaction(budget_data)
#
# File /opt/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py:1282, in Kernel.raw_input(self, prompt)
#    1280     msg = "raw_input was called, but this frontend does not support input requests."
#    1281     raise StdinNotImplementedError(msg)
# -> 1282 return self._input_request(
#    1283     str(prompt),
#    1284     self._parent_ident["shell"],
#    1285     self.get_parent("shell"),
#    1286     password=False,
#    1287 )
#
# File /opt/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py:1325, in Kernel._input_request(self, prompt, ident, parent, password)
#    1322 except KeyboardInterrupt:
#    1323     # re-raise KeyboardInterrupt, to truncate traceback
#    1324     msg = "Interrupted by user"
# -> 1325     raise KeyboardInterrupt(msg) from None
#    1326 except Exception:
#    1327     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
